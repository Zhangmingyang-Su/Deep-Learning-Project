# %% [markdown]
# # Advertising Analytics Click Prediction:
# ####[Ad impressions with clicks dataset](https://www.kaggle.com/c/avazu-ctr-prediction/data)
#
# <img src="/files/img/fraud_ml_pipeline.png" alt="workflow" width="500">
#
# This is the SQL/Data exploration notebook for the series of Advertising Analytics Click Prediction notebooks.  For this stage, we will focus the Exploration of data.

# %%
impression = spark.read.load("/FileStore/tables/filtered_train.csv", format = 'csv', header = True)
impression.createOrReplaceTempView("impression")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql describe impression
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>_c0</td><td>string</td><td>null</td></tr><tr><td>id</td><td>string</td><td>null</td></tr><tr><td>click</td><td>string</td><td>null</td></tr><tr><td>hour</td><td>string</td><td>null</td></tr><tr><td>C1</td><td>string</td><td>null</td></tr><tr><td>banner_pos</td><td>string</td><td>null</td></tr><tr><td>site_id</td><td>string</td><td>null</td></tr><tr><td>site_domain</td><td>string</td><td>null</td></tr><tr><td>site_category</td><td>string</td><td>null</td></tr><tr><td>app_id</td><td>string</td><td>null</td></tr><tr><td>app_domain</td><td>string</td><td>null</td></tr><tr><td>app_category</td><td>string</td><td>null</td></tr><tr><td>device_id</td><td>string</td><td>null</td></tr><tr><td>device_ip</td><td>string</td><td>null</td></tr><tr><td>device_model</td><td>string</td><td>null</td></tr><tr><td>device_type</td><td>string</td><td>null</td></tr><tr><td>device_conn_type</td><td>string</td><td>null</td></tr><tr><td>C14</td><td>string</td><td>null</td></tr><tr><td>C15</td><td>string</td><td>null</td></tr><tr><td>C16</td><td>string</td><td>null</td></tr><tr><td>C17</td><td>string</td><td>null</td></tr><tr><td>C18</td><td>string</td><td>null</td></tr><tr><td>C19</td><td>string</td><td>null</td></tr><tr><td>C20</td><td>string</td><td>null</td></tr><tr><td>C21</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql select banner_pos, count(1)
from impression
group by 1 order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>banner_pos</th><th>count(1)</th></tr></thead><tbody><tr><td>0</td><td>291180</td></tr><tr><td>1</td><td>112416</td></tr><tr><td>2</td><td>111</td></tr><tr><td>3</td><td>20</td></tr><tr><td>4</td><td>69</td></tr><tr><td>5</td><td>57</td></tr><tr><td>7</td><td>437</td></tr></tbody></table></div>

# %%
# %sql select banner_pos,
sum(case when click = 1 then 1 else 0 end) as click,
sum(case when click = 0 then 1 else 0 end) as no_click
from impression group by 1 order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>banner_pos</th><th>click</th><th>no_click</th></tr></thead><tbody><tr><td>0</td><td>47939</td><td>243241</td></tr><tr><td>1</td><td>20542</td><td>91874</td></tr><tr><td>2</td><td>12</td><td>99</td></tr><tr><td>3</td><td>5</td><td>15</td></tr><tr><td>4</td><td>12</td><td>57</td></tr><tr><td>5</td><td>6</td><td>51</td></tr><tr><td>7</td><td>139</td><td>298</td></tr></tbody></table></div>

# %%
# %sql select banner_pos,
sum(case when click = 1 then 1 else 0 end) / (count(1) * 1.0) as CTR
from impression group by 1 order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>banner_pos</th><th>CTR</th></tr></thead><tbody><tr><td>0</td><td>0.164636994299059</td></tr><tr><td>1</td><td>0.18273199544548818</td></tr><tr><td>2</td><td>0.10810810810810811</td></tr><tr><td>3</td><td>0.25</td></tr><tr><td>4</td><td>0.17391304347826086</td></tr><tr><td>5</td><td>0.10526315789473684</td></tr><tr><td>7</td><td>0.3180778032036613</td></tr></tbody></table></div>

# %%
# %sql select device_type, count(1)
from impression
group by 1 order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_type</th><th>count(1)</th></tr></thead><tbody><tr><td>0</td><td>22063</td></tr><tr><td>1</td><td>373227</td></tr><tr><td>4</td><td>7703</td></tr><tr><td>5</td><td>1297</td></tr></tbody></table></div>

# %%
# %sql select device_type,
sum(case when click = 1 then 1 else 0 end) as click,
sum(case when click = 0 then 1 else 0 end) as no_click
from impression group by 1 order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_type</th><th>click</th><th>no_click</th></tr></thead><tbody><tr><td>0</td><td>4781</td><td>17282</td></tr><tr><td>1</td><td>63033</td><td>310194</td></tr><tr><td>4</td><td>731</td><td>6972</td></tr><tr><td>5</td><td>110</td><td>1187</td></tr></tbody></table></div>

# %%
# %sql select device_type,
sum(case when click = 1 then 1 else 0 end) / (count(1) * 1.0) as CTR
from impression group by 1 order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_type</th><th>CTR</th></tr></thead><tbody><tr><td>0</td><td>0.21669763858042876</td></tr><tr><td>1</td><td>0.16888649535001488</td></tr><tr><td>4</td><td>0.09489809165260288</td></tr><tr><td>5</td><td>0.08481110254433308</td></tr></tbody></table></div>

# %%
# %sql select site_category, count(1) as count
from impression
group by 1 having count > 200 order by count desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>site_category</th><th>count</th></tr></thead><tbody><tr><td>50e219e0</td><td>165632</td></tr><tr><td>f028772b</td><td>126494</td></tr><tr><td>28905ebd</td><td>73611</td></tr><tr><td>3e814130</td><td>30335</td></tr><tr><td>f66779e6</td><td>2548</td></tr><tr><td>75fa27f6</td><td>1662</td></tr><tr><td>335d28a8</td><td>1339</td></tr><tr><td>76b2941d</td><td>1107</td></tr><tr><td>c0dd3be3</td><td>426</td></tr><tr><td>72722551</td><td>287</td></tr><tr><td>dedf689d</td><td>265</td></tr><tr><td>70fb0e29</td><td>251</td></tr></tbody></table></div>

# %%
# %sql select site_category,
sum(case when click = 1 then 1 else 0 end) as click,
sum(case when click = 0 then 1 else 0 end) as no_click
from impression group by 1 order by 3 desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>site_category</th><th>click</th><th>no_click</th></tr></thead><tbody><tr><td>50e219e0</td><td>21349</td><td>144283</td></tr><tr><td>f028772b</td><td>22664</td><td>103830</td></tr><tr><td>28905ebd</td><td>15399</td><td>58212</td></tr><tr><td>3e814130</td><td>8536</td><td>21799</td></tr><tr><td>f66779e6</td><td>118</td><td>2430</td></tr><tr><td>75fa27f6</td><td>175</td><td>1487</td></tr><tr><td>335d28a8</td><td>117</td><td>1222</td></tr><tr><td>76b2941d</td><td>23</td><td>1084</td></tr><tr><td>c0dd3be3</td><td>51</td><td>375</td></tr><tr><td>72722551</td><td>26</td><td>261</td></tr><tr><td>70fb0e29</td><td>43</td><td>208</td></tr><tr><td>0569f928</td><td>6</td><td>155</td></tr><tr><td>dedf689d</td><td>135</td><td>130</td></tr><tr><td>8fd0aea4</td><td>2</td><td>72</td></tr><tr><td>42a36e14</td><td>9</td><td>28</td></tr><tr><td>a818d37a</td><td>0</td><td>28</td></tr><tr><td>bcf865d9</td><td>0</td><td>14</td></tr><tr><td>e787de0e</td><td>0</td><td>10</td></tr><tr><td>5378d028</td><td>2</td><td>4</td></tr><tr><td>a72a0145</td><td>0</td><td>1</td></tr><tr><td>c706e647</td><td>0</td><td>1</td></tr><tr><td>9ccfa2ea</td><td>0</td><td>1</td></tr></tbody></table></div>

# %%
# %sql select site_category,
sum(case when click = 1 then 1 else 0 end) / (count(1) * 1.0) as CTR
from impression group by 1 order by 2 desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>site_category</th><th>CTR</th></tr></thead><tbody><tr><td>dedf689d</td><td>0.5094339622641509</td></tr><tr><td>5378d028</td><td>0.3333333333333333</td></tr><tr><td>3e814130</td><td>0.2813911323553651</td></tr><tr><td>42a36e14</td><td>0.24324324324324323</td></tr><tr><td>28905ebd</td><td>0.2091942780290989</td></tr><tr><td>f028772b</td><td>0.1791705535440416</td></tr><tr><td>70fb0e29</td><td>0.17131474103585656</td></tr><tr><td>50e219e0</td><td>0.12889417503863987</td></tr><tr><td>c0dd3be3</td><td>0.11971830985915494</td></tr><tr><td>75fa27f6</td><td>0.10529482551143202</td></tr><tr><td>72722551</td><td>0.09059233449477352</td></tr><tr><td>335d28a8</td><td>0.08737864077669903</td></tr><tr><td>f66779e6</td><td>0.04631083202511774</td></tr><tr><td>0569f928</td><td>0.03726708074534161</td></tr><tr><td>8fd0aea4</td><td>0.02702702702702703</td></tr><tr><td>76b2941d</td><td>0.02077687443541102</td></tr><tr><td>a818d37a</td><td>0.0</td></tr><tr><td>e787de0e</td><td>0.0</td></tr><tr><td>a72a0145</td><td>0.0</td></tr><tr><td>c706e647</td><td>0.0</td></tr><tr><td>bcf865d9</td><td>0.0</td></tr><tr><td>9ccfa2ea</td><td>0.0</td></tr></tbody></table></div>

# %%
# %sql select substr(hour, 7) as hour, 
count(1)
from impression 
group by 1 order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hour</th><th>count(1)</th></tr></thead><tbody><tr><td>00</td><td>8531</td></tr><tr><td>01</td><td>9928</td></tr><tr><td>02</td><td>12282</td></tr><tr><td>03</td><td>14112</td></tr><tr><td>04</td><td>18990</td></tr><tr><td>05</td><td>19625</td></tr><tr><td>06</td><td>17741</td></tr><tr><td>07</td><td>18637</td></tr><tr><td>08</td><td>20991</td></tr><tr><td>09</td><td>22747</td></tr><tr><td>10</td><td>21362</td></tr><tr><td>11</td><td>20585</td></tr><tr><td>12</td><td>22253</td></tr><tr><td>13</td><td>23907</td></tr><tr><td>14</td><td>21943</td></tr><tr><td>15</td><td>20863</td></tr><tr><td>16</td><td>20252</td></tr><tr><td>17</td><td>20547</td></tr><tr><td>18</td><td>17674</td></tr><tr><td>19</td><td>13180</td></tr><tr><td>20</td><td>11176</td></tr><tr><td>21</td><td>9741</td></tr><tr><td>22</td><td>9078</td></tr><tr><td>23</td><td>8145</td></tr></tbody></table></div>

# %%
# %sql select substr(hour, 7) as hour,
sum(case when click = 1 then 1 else 0 end) as click,
sum(case when click = 0 then 1 else 0 end) as no_click
from impression group by 1 order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hour</th><th>click</th><th>no_click</th></tr></thead><tbody><tr><td>00</td><td>1572</td><td>6959</td></tr><tr><td>01</td><td>1811</td><td>8117</td></tr><tr><td>02</td><td>2134</td><td>10148</td></tr><tr><td>03</td><td>2436</td><td>11676</td></tr><tr><td>04</td><td>3089</td><td>15901</td></tr><tr><td>05</td><td>3193</td><td>16432</td></tr><tr><td>06</td><td>3058</td><td>14683</td></tr><tr><td>07</td><td>3346</td><td>15291</td></tr><tr><td>08</td><td>3387</td><td>17604</td></tr><tr><td>09</td><td>3591</td><td>19156</td></tr><tr><td>10</td><td>3429</td><td>17933</td></tr><tr><td>11</td><td>3534</td><td>17051</td></tr><tr><td>12</td><td>3870</td><td>18383</td></tr><tr><td>13</td><td>3982</td><td>19925</td></tr><tr><td>14</td><td>3836</td><td>18107</td></tr><tr><td>15</td><td>3849</td><td>17014</td></tr><tr><td>16</td><td>3593</td><td>16659</td></tr><tr><td>17</td><td>3596</td><td>16951</td></tr><tr><td>18</td><td>2959</td><td>14715</td></tr><tr><td>19</td><td>2101</td><td>11079</td></tr><tr><td>20</td><td>1807</td><td>9369</td></tr><tr><td>21</td><td>1582</td><td>8159</td></tr><tr><td>22</td><td>1479</td><td>7599</td></tr><tr><td>23</td><td>1421</td><td>6724</td></tr></tbody></table></div>

# %%
# %sql select substr(hour, 7) as hour,
sum(case when click = 1 then 1 else 0 end) / (count(1) * 1.0) as CTR
from impression group by 1 order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hour</th><th>CTR</th></tr></thead><tbody><tr><td>00</td><td>0.18426913609190013</td></tr><tr><td>01</td><td>0.1824133763094279</td></tr><tr><td>02</td><td>0.17375020354991044</td></tr><tr><td>03</td><td>0.17261904761904762</td></tr><tr><td>04</td><td>0.16266456029489204</td></tr><tr><td>05</td><td>0.16270063694267517</td></tr><tr><td>06</td><td>0.17236908855194183</td></tr><tr><td>07</td><td>0.17953533293985083</td></tr><tr><td>08</td><td>0.161354866371302</td></tr><tr><td>09</td><td>0.1578669714687651</td></tr><tr><td>10</td><td>0.16051867802640202</td></tr><tr><td>11</td><td>0.1716784066067525</td></tr><tr><td>12</td><td>0.1739091358468521</td></tr><tr><td>13</td><td>0.16656209478395448</td></tr><tr><td>14</td><td>0.17481657020462105</td></tr><tr><td>15</td><td>0.18448928725494895</td></tr><tr><td>16</td><td>0.17741457633813945</td></tr><tr><td>17</td><td>0.175013383948995</td></tr><tr><td>18</td><td>0.16742107049903815</td></tr><tr><td>19</td><td>0.1594081942336874</td></tr><tr><td>20</td><td>0.1616857551896922</td></tr><tr><td>21</td><td>0.16240632378605893</td></tr><tr><td>22</td><td>0.16292134831460675</td></tr><tr><td>23</td><td>0.17446286065070596</td></tr></tbody></table></div>

# %%
# %sql select 
count(1) as total,

count(distinct C1) as C1,
count(distinct banner_pos) as banner_pos,
count(distinct site_id) as site_id,
count(distinct site_domain) as site_domain,
count(distinct site_category) as site_category,
count(distinct app_id) as app_id,
count(distinct app_domain) as app_domain,
count(distinct app_category) as app_category,
count(distinct device_id) as device_id,
count(distinct device_ip) as device_ip,
count(distinct device_model) as device_model,
count(distinct device_type) as device_type,
count(distinct device_conn_type) as device_conn_type,
count(distinct C14) as C14,
count(distinct C15) as C15,
count(distinct C16) as C16,
count(distinct C17) as C17,
count(distinct C18) as C18,
count(distinct C19) as C19,
count(distinct C20) as C20,
count(distinct C21) as C21
from impression
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>